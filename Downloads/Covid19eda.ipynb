# %%
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df= pd.read_csv("D:\programming\covid19.csv")
df
# Out:
#      Country   Total Cases New Cases Total Deaths  New Deaths Total Recovered  \
# 0        USA  11,13,67,209       NaN    11,99,031         NaN    10,90,53,249
# 1      India   4,50,28,429       161     5,33,475         2.0             NaN
# 2     France   4,01,38,560       NaN     1,67,642         NaN     3,99,70,918
# 3    Germany   3,88,19,284       574     1,82,439        28.0     3,82,40,600
# 4     Brazil   3,84,07,327       NaN     7,09,765         NaN     3,62,49,161
# ..       ...           ...       ...          ...         ...             ...
# 234   Total:   6,97,91,773       NaN    13,65,551         NaN     6,66,48,277
# 235   Total:   1,48,26,780     1,345       32,665         NaN     1,45,72,565
# 236   Total:   1,28,59,770       NaN     2,58,884         NaN     1,20,89,899
# 237   Total:           721       NaN           15         NaN             706
# 238   Total:  70,35,31,128     2,446    69,85,004        37.0    67,43,03,837
#
# ...

# %%
# knowing about the dataB
df.shape
# Out:
# (239, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            239 non-null    object
#  1   Total Cases        239 non-null    object
#  2   New Cases          12 non-null     object
#  3   Total Deaths       234 non-null    object
#  4   New Deaths         7 non-null      float64
#  5   Total Recovered    190 non-null    object
#  6   New Recovered      17 non-null     object
#  7   Active Cases       191 non-null    object
#  8   Serious, Critical  60 non-null     object
#  9   Tot Cases/1M pop   230 non-null    object
#  10  Deaths/1M pop      225 non-null    object
#  11  Total Tests        213 non-null    object
#  12  Tests/1M pop       213 non-null    object
#  13  Population         229 non-null    object
# dtypes: float64(1), object(13)
# memory usage: 26.3+ KB

# %%
df.head(10)
# Out:
#     Country   Total Cases New Cases Total Deaths  New Deaths Total Recovered  \
# 0       USA  11,13,67,209       NaN    11,99,031         NaN    10,90,53,249
# 1     India   4,50,28,429       161     5,33,475         2.0             NaN
# 2    France   4,01,38,560       NaN     1,67,642         NaN     3,99,70,918
# 3   Germany   3,88,19,284       574     1,82,439        28.0     3,82,40,600
# 4    Brazil   3,84,07,327       NaN     7,09,765         NaN     3,62,49,161
# 5  S. Korea   3,45,71,873       NaN       35,934         NaN     3,45,35,939
# 6     Japan   3,38,03,572       NaN       74,694         NaN             NaN
# 7     Italy   2,67,16,804       NaN     1,96,257         NaN     2,63,47,863
# 8        UK   2,48,98,914       NaN     2,32,112         NaN     2,46,55,170
# 9    Russia   2,39,57,146       NaN     4,02,264         NaN     2,33,70,779
#
#   New Recovered Active Cases Serious, Critical Tot Cases/1M pop Deaths/1M pop  \
# ...

# %%
df.count()
# Out:
# Country              239
# Total Cases          239
# New Cases             12
# Total Deaths         234
# New Deaths             7
# Total Recovered      190
# New Recovered         17
# Active Cases         191
# Serious, Critical     60
# Tot Cases/1M pop     230
# Deaths/1M pop        225
# Total Tests          213
# Tests/1M pop         213
# Population           229
# dtype: int64

# %%
# checking number of null values
print(df.isnull().sum())
print("\n \ntotal null values",df.isnull().sum().sum())
# Out:
# Country                0
# Total Cases            0
# New Cases            227
# Total Deaths           5
# New Deaths           232
# Total Recovered       49
# New Recovered        222
# Active Cases          48
# Serious, Critical    179
# Tot Cases/1M pop       9
# Deaths/1M pop         14
# Total Tests           26
# Tests/1M pop          26
# Population            10
# dtype: int64
#
#
# total null values 1047

# %%
df.rename(columns={"Total Cases": ""})
# Out:
#   Cell In[10], line 1
#     sns.heatmap(Total Cases)
#                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
sns.heatmap(data=df["Total Cases"])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sns.heatmap(data=df["Total Cases"])
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# ...
